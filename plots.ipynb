# %%
import pickle

# %%
with open('metrics/metric_dict_efficientNet_B0_finetuned_model.pkl','rb') as f:
    data= pickle.load(f)

# %%
with open('metrics/metric_dict_TinyVGG_base_model.pkl','rb') as f:
    data1 = pickle.load(f)

# %%
with open('metrics/metric_dict_resnet_18_finetuned_model.pkl','rb') as f:
    data2 = pickle.load(f)

# %%
with open('metrics/metric_dict_vit_B16_finetuned_model.pkl','rb') as f:
    data3 = pickle.load(f)

# %%
import numpy as np
import matplotlib.pyplot as plt
array = np.arange(0,100,1)
plt.plot(array,data['train_loss'],color='r')
plt.plot(array,data1['train_loss'],color='g')
plt.plot(array,data2['train_loss'],color='c')
plt.plot(array,data3['train_loss'],color='b')

# %%
plt.plot(array,data['test_loss'],color='r')
plt.plot(array,data1['test_loss'],color='g')
plt.plot(array,data2['test_loss'],color='c')
plt.plot(array,data3['test_loss'],color='b')

# %%
plt.plot(array,data['train_acc'],color='r')
plt.plot(array,data1['train_acc'],color='g')
plt.plot(array,data2['train_acc'],color='c')
plt.plot(array,data3['train_acc'],color='b')

# %%
plt.plot(array,data['test_acc'],color='r')
plt.plot(array,data1['test_acc'],color='g')
plt.plot(array,data2['test_acc'],color='c')
plt.plot(array,data3['test_acc'],color='b')
